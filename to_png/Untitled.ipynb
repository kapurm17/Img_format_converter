# %%
import PIL
from PIL import Image
import os

# %%
files = os.listdir()
for f in files:
    if ".jpg" in f:
        print(f)
        img = Image.open(f)
        img = img.resize((500, 500), PIL.Image.ANTIALIAS)
        img.save(f[:-3] + "png")
# Out:
# Oleh Musiy_National University of Ostroh Academy.jpg
# Olga KobyakovaRector_Siberian State Medical University.jpg

# %%
# Out:
# photo.jpg

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x848 at 0x24F041919E8>

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x24F0422E358>

# %%
# Out:
# ['.ipynb_checkpoints', 'photo.jpg', 'photo.png', 'Untitled.ipynb']
